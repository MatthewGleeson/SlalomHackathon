# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize

# %%
df = pd.read_csv('codeKeywords.csv')

# %%
y = df['code']

y=y.astype(str).str[:2]

df['code']=y

df.to_csv('codeKeywordsFirst2Chars.csv', index='False')

# %%
def modifierFunction(row):
    
    s = str(row['code'])
    row['code'] = s[:2]
    print(row['code'])

# %%
df.apply(modifierFunction,axis=1)
# Out:
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                            keywords code
# 0           0               Alternative Education  B20
# 1           1                    Boarding Schools  B20
# 2           2  Child Development Education Issues  B20
# 3           3             Community-Based Schools  B20
# 4           4          Community Learning Centers  B20
# 5           5            Extended-Service Schools  B20
# 6           6                Full-Service Schools  B20
# 7           7                Home-Based Education  B20
# 8           8                      Home Education  B20
# 9           9                      Home Schooling  B20
