# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize

# %%
df = pd.read_csv('spreadOutKeywords.csv')

# %%
def modifierFunction(code):
    s = str(code)
    code = s[:2]
    print(code)

# %%
df = df.apply(modifierFunction,axis=0)
# Out:
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B2
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B3
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B5
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B6
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B7
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# B9
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                            keywords  code
# 0           0               Alternative Education  None
# 1           1                    Boarding Schools  None
# 2           2  Child Development Education Issues  None
# 3           3             Community-Based Schools  None
# 4           4          Community Learning Centers  None
# 5           5            Extended-Service Schools  None
# 6           6                Full-Service Schools  None
# 7           7                Home-Based Education  None
# 8           8                      Home Education  None
# 9           9                      Home Schooling  None
